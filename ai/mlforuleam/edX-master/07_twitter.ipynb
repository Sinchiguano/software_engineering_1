# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret (Click on Create Access Token to create those). Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in /home/zonca/anaconda/lib/python3.5/site-packages

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7f983401edd8>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'as_of': '2017-05-08T05:57:50Z',
#   'created_at': '2017-05-08T05:53:27Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': '#MTVAwards',
#     'promoted_content': None,
#     'query': '%23MTVAwards',
#     'tweet_volume': 1078929,
#     'url': 'http://twitter.com/search?q=%23MTVAwards'},
#    {'name': '#MasterChefMx',
#     'promoted_content': None,
#     'query': '%23MasterChefMx',
#     'tweet_volume': 39744,
#     'url': 'http://twitter.com/search?q=%23MasterChefMx'},
#    {'name': '#CorazonesRotosMC',
#     'promoted_content': None,
#     'query': '%23CorazonesRotosMC',
#     'tweet_volume': 13996,
#     'url': 'http://twitter.com/search?q=%23CorazonesRotosMC'},
#    {'name': 'Joe West',
#     'promoted_content': None,
#     'query': '%22Joe+West%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Joe+West%22'},
#    {'name': '#حاجات_تفتح_نفسي',
#     'promoted_content': None,
#     'query': '%23%D8%AD%D8%A7%D8%AC%D8%A7%D8%AA_%D8%AA%D9%81%D8%AA%D8%AD_%D9%86%D9%81%D8%B3%D9%8A',
#     'tweet_volume': 28268,
#     'url': 'http://twitter.com/search?q=%23%D8%AD%D8%A7%D8%AC%D8%A7%D8%AA_%D8%AA%D9%81%D8%AA%D8%AD_%D9%86%D9%81%D8%B3%D9%8A'},
#    {'name': '#RHOA',
#     'promoted_content': None,
#     'query': '%23RHOA',
#     'tweet_volume': 115361,
#     'url': 'http://twitter.com/search?q=%23RHOA'},
#    {'name': 'Guerra Mundial Z',
#     'promoted_content': None,
#     'query': '%22Guerra+Mundial+Z%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Guerra+Mundial+Z%22'},
#    {'name': 'Stranger Things',
#     'promoted_content': None,
#     'query': '%22Stranger+Things%22',
#     'tweet_volume': 66201,
#     'url': 'http://twitter.com/search?q=%22Stranger+Things%22'},
#    {'name': 'GW明け',
#     'promoted_content': None,
#     'query': 'GW%E6%98%8E%E3%81%91',
#     'tweet_volume': 67452,
#     'url': 'http://twitter.com/search?q=GW%E6%98%8E%E3%81%91'},
#    {'name': 'Erica Rivas',
#     'promoted_content': None,
#     'query': '%22Erica+Rivas%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Erica+Rivas%22'},
#    {'name': 'Jake Arrieta',
#     'promoted_content': None,
#     'query': '%22Jake+Arrieta%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Jake+Arrieta%22'},
#    {'name': '#سقوط_طالب_من_الدرج',
#     'promoted_content': None,
#     'query': '%23%D8%B3%D9%82%D9%88%D8%B7_%D8%B7%D8%A7%D9%84%D8%A8_%D9%85%D9%86_%D8%A7%D9%84%D8%AF%D8%B1%D8%AC',
#     'tweet_volume': 13940,
#     'url': 'http://twitter.com/search?q=%23%D8%B3%D9%82%D9%88%D8%B7_%D8%B7%D8%A7%D9%84%D8%A8_%D9%85%D9%86_%D8%A7%D9%84%D8%AF%D8%B1%D8%AC'},
#    {'name': '#FelizLunes',
#     'promoted_content': None,
#     'query': '%23FelizLunes',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23FelizLunes'},
#    {'name': '#무엇을_어디에_넣어줄지_말해보자',
#     'promoted_content': None,
#     'query': '%23%EB%AC%B4%EC%97%87%EC%9D%84_%EC%96%B4%EB%94%94%EC%97%90_%EB%84%A3%EC%96%B4%EC%A4%84%EC%A7%80_%EB%A7%90%ED%95%B4%EB%B3%B4%EC%9E%90',
#     'tweet_volume': 14082,
#     'url': 'http://twitter.com/search?q=%23%EB%AC%B4%EC%97%87%EC%9D%84_%EC%96%B4%EB%94%94%EC%97%90_%EB%84%A3%EC%96%B4%EC%A4%84%EC%A7%80_%EB%A7%90%ED%95%B4%EB%B3%B4%EC%9E%90'},
#    {'name': '#PurposeTourManila',
#     'promoted_content': None,
#     'query': '%23PurposeTourManila',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PurposeTourManila'},
#    {'name': '#MejorHablar',
#     'promoted_content': None,
#     'query': '%23MejorHablar',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MejorHablar'},
#    {'name': '#VenezuelaUrgente',
#     'promoted_content': None,
#     'query': '%23VenezuelaUrgente',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23VenezuelaUrgente'},
#    {'name': '#JesusCristoEstáVivo',
#     'promoted_content': None,
#     'query': '%23JesusCristoEst%C3%A1Vivo',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23JesusCristoEst%C3%A1Vivo'},
#    {'name': '#MLBxESPN',
#     'promoted_content': None,
#     'query': '%23MLBxESPN',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MLBxESPN'},
#    {'name': '#محمد_بن_سلمان_يزلزل_ايران',
#     'promoted_content': None,
#     'query': '%23%D9%85%D8%AD%D9%85%D8%AF_%D8%A8%D9%86_%D8%B3%D9%84%D9%85%D8%A7%D9%86_%D9%8A%D8%B2%D9%84%D8%B2%D9%84_%D8%A7%D9%8A%D8%B1%D8%A7%D9%86',
#     'tweet_volume': 26888,
#     'url': 'http://twitter.com/search?q=%23%D9%85%D8%AD%D9%85%D8%AF_%D8%A8%D9%86_%D8%B3%D9%84%D9%85%D8%A7%D9%86_%D9%8A%D8%B2%D9%84%D8%B2%D9%84_%D8%A7%D9%8A%D8%B1%D8%A7%D9%86'},
#    {'name': '#EnLiguillaVoy',
#     'promoted_content': None,
#     'query': '%23EnLiguillaVoy',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23EnLiguillaVoy'},
#    {'name': '#SegundaComClubeSDV',
#     'promoted_content': None,
#     'query': '%23SegundaComClubeSDV',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SegundaComClubeSDV'},
#    {'name': '#نغرد_عشان',
#     'promoted_content': None,
#     'query': '%23%D9%86%D8%BA%D8%B1%D8%AF_%D8%B9%D8%B4%D8%A7%D9%86',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D9%86%D8%BA%D8%B1%D8%AF_%D8%B9%D8%B4%D8%A7%D9%86'},
#    {'name': '#FodderScam',
#     'promoted_content': None,
#     'query': '%23FodderScam',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23FodderScam'},
#    {'name': '#AltaTensión',
#     'promoted_content': None,
#     'query': '%23AltaTensi%C3%B3n',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23AltaTensi%C3%B3n'},
#    {'name': '#AmericanRaceTNT',
#     'promoted_content': None,
#     'query': '%23AmericanRaceTNT',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23AmericanRaceTNT'},
#    {'name': '#OnceUponAMusical',
#     'promoted_content': None,
#     'query': '%23OnceUponAMusical',
#     'tweet_volume': 62479,
#     'url': 'http://twitter.com/search?q=%23OnceUponAMusical'},
#    {'name': '#ProfileInCourage',
#     'promoted_content': None,
#     'query': '%23ProfileInCourage',
#     'tweet_volume': 38825,
#     'url': 'http://twitter.com/search?q=%23ProfileInCourage'},
#    {'name': '#ShowtimeMAYForever',
#     'promoted_content': None,
#     'query': '%23ShowtimeMAYForever',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ShowtimeMAYForever'},
#    {'name': '#pazartesi',
#     'promoted_content': None,
#     'query': '%23pazartesi',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23pazartesi'},
#    {'name': '#unite2017tokyo',
#     'promoted_content': None,
#     'query': '%23unite2017tokyo',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23unite2017tokyo'},
#    {'name': '#DANCEDANCE',
#     'promoted_content': None,
#     'query': '%23DANCEDANCE',
#     'tweet_volume': 35335,
#     'url': 'http://twitter.com/search?q=%23DANCEDANCE'},
#    {'name': '#kokkai',
#     'promoted_content': None,
#     'query': '%23kokkai',
#     'tweet_volume': 14538,
#     'url': 'http://twitter.com/search?q=%23kokkai'},
#    {'name': '#iBribedKejriwal',
#     'promoted_content': None,
#     'query': '%23iBribedKejriwal',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23iBribedKejriwal'},
#    {'name': '#في_حبك_قلت',
#     'promoted_content': None,
#     'query': '%23%D9%81%D9%8A_%D8%AD%D8%A8%D9%83_%D9%82%D9%84%D8%AA',
#     'tweet_volume': 63619,
#     'url': 'http://twitter.com/search?q=%23%D9%81%D9%8A_%D8%AD%D8%A8%D9%83_%D9%82%D9%84%D8%AA'},
#    {'name': '#صباحات_الاهلي',
#     'promoted_content': None,
#     'query': '%23%D8%B5%D8%A8%D8%A7%D8%AD%D8%A7%D8%AA_%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%B5%D8%A8%D8%A7%D8%AD%D8%A7%D8%AA_%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A'},
#    {'name': '#NoMeGustaQue',
#     'promoted_content': None,
#     'query': '%23NoMeGustaQue',
#     'tweet_volume': 11318,
#     'url': 'http://twitter.com/search?q=%23NoMeGustaQue'},
#    {'name': '#MTVActAppVillalobos',
#     'promoted_content': None,
#     'query': '%23MTVActAppVillalobos',
#     'tweet_volume': 166316,
#     'url': 'http://twitter.com/search?q=%23MTVActAppVillalobos'},
#    {'name': '#DeboDecir',
#     'promoted_content': None,
#     'query': '%23DeboDecir',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23DeboDecir'},
#    {'name': '#MagicianDatingProblems',
#     'promoted_content': None,
#     'query': '%23MagicianDatingProblems',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MagicianDatingProblems'},
#    {'name': '#LaVozKids',
#     'promoted_content': None,
#     'query': '%23LaVozKids',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23LaVozKids'},
#    {'name': '#BillionsSeasonFinale',
#     'promoted_content': None,
#     'query': '%23BillionsSeasonFinale',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23BillionsSeasonFinale'},
#    {'name': '#IntoTheBadlands',
#     'promoted_content': None,
#     'query': '%23IntoTheBadlands',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23IntoTheBadlands'},
#    {'name': '#EntMEWomen',
#     'promoted_content': None,
#     'query': '%23EntMEWomen',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23EntMEWomen'},
#    {'name': '#SinMiedoTuca',
#     'promoted_content': None,
#     'query': '%23SinMiedoTuca',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SinMiedoTuca'},
#    {'name': '#اجد_في_عيناك',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D8%AC%D8%AF_%D9%81%D9%8A_%D8%B9%D9%8A%D9%86%D8%A7%D9%83',
#     'tweet_volume': 18045,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D8%AC%D8%AF_%D9%81%D9%8A_%D8%B9%D9%8A%D9%86%D8%A7%D9%83'},
#    {'name': '#تجمع_التربيه_الخاصه_بجده2',
#     'promoted_content': None,
#     'query': '%23%D8%AA%D8%AC%D9%85%D8%B9_%D8%A7%D9%84%D8%AA%D8%B1%D8%A8%D9%8A%D9%87_%D8%A7%D9%84%D8%AE%D8%A7%D8%B5%D9%87_%D8%A8%D8%AC%D8%AF%D9%872',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%AA%D8%AC%D9%85%D8%B9_%D8%A7%D9%84%D8%AA%D8%B1%D8%A8%D9%8A%D9%87_%D8%A7%D9%84%D8%AE%D8%A7%D8%B5%D9%87_%D8%A8%D8%AC%D8%AF%D9%872'},
#    {'name': '#Independiente',
#     'promoted_content': None,
#     'query': '%23Independiente',
#     'tweet_volume': 12124,
#     'url': 'http://twitter.com/search?q=%23Independiente'},
#    {'name': '#SallyYatesIsAPatriot',
#     'promoted_content': None,
#     'query': '%23SallyYatesIsAPatriot',
#     'tweet_volume': 105190,
#     'url': 'http://twitter.com/search?q=%23SallyYatesIsAPatriot'},
#    {'name': '#DafBama2017_SuperJunior',
#     'promoted_content': None,
#     'query': '%23DafBama2017_SuperJunior',
#     'tweet_volume': 20857,
#     'url': 'http://twitter.com/search?q=%23DafBama2017_SuperJunior'}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['as_of', 'created_at', 'trends', 'locations']
'query': '%22Kings+of+Leon%22', 'tweet_volume': None}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Princess+Diana%22', 'name': 'Princess Diana', 'query': '%22Princess+Diana%22', 'tweet_volume': None}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Big+Sean%22', 'name': 'Big Sean', 'query': '%22Big+Sean%22', 'tweet_volume': 36977}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23ProfileInCourage', 'name': '#ProfileInCourage', 'query': '%23ProfileInCourage', 'tweet_volume': 38825}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23digitalhealth', 'name': '#digitalhealth', 'query': '%23digitalhealth', 'tweet_volume': None}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23Yankees', 'name': '#Yankees', 'query': '%23Yankees', 'tweet_volume': 11203}, {'promoted_content': None, ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "as_of": "2017-05-08T05:57:50Z",
#   "created_at": "2017-05-08T05:53:27Z",
#   "trends": [
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Joe+West%22",
#     "name": "Joe West",
#     "query": "%22Joe+West%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23RHOA",
#     "name": "#RHOA",
#     "query": "%23RHOA",
#     "tweet_volume": 115361
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23MTVAwards",
#     "name": "#MTVAwards",
#     "query": "%23MTVAwards",
#     "tweet_volume": 1078929
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23AmericanRaceTNT",
#     "name": "#AmericanRaceTNT",
#     "query": "%23AmericanRaceTNT",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23ProfileInCourage",
#     "name": "#ProfileInCourage",
#     "query": "%23ProfileInCourage",
#     "tweet_volume": 38825
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23Billions",
#     "name": "#Billions",
#     "query": "%23Billions",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Chasen+Shreve%22",
#     "name": "Chasen Shreve",
#     "query": "%22Chasen+Shreve%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Jake+Arrieta%22",
#     "name": "Jake Arrieta",
#     "query": "%22Jake+Arrieta%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Wade+Davis%22",
#     "name": "Wade Davis",
#     "query": "%22Wade+Davis%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Chris+Carter%22",
#     "name": "Chris Carter",
#     "query": "%22Chris+Carter%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Cheesecake+Factory%22",
#     "name": "Cheesecake Factory",
#     "query": "%22Cheesecake+Factory%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=Bryant",
#     "name": "Bryant",
#     "query": "Bryant",
#     "tweet_volume": 13697
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Brian+Duensing%22",
#     "name": "Brian Duensing",
#     "query": "%22Brian+Duensing%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Patrick+Beverley%22",
#     "name": "Patrick Beverley",
#     "query": "%22Patrick+Beverley%22",
#     "tweet_volume": 10006
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Aaron+Boone%22",
#     "name": "Aaron Boone",
#     "query": "%22Aaron+Boone%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Bobby+Brown%22",
#     "name": "Bobby Brown",
#     "query": "%22Bobby+Brown%22",
#     "tweet_volume": 21613
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Stranger+Things%22",
#     "name": "Stranger Things",
#     "query": "%22Stranger+Things%22",
#     "tweet_volume": 66201
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Jump+Out+The+Window%22",
#     "name": "Jump Out The Window",
#     "query": "%22Jump+Out+The+Window%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Adam+Warren%22",
#     "name": "Adam Warren",
#     "query": "%22Adam+Warren%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22New+MLB%22",
#     "name": "New MLB",
#     "query": "%22New+MLB%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Eric+Gordon%22",
#     "name": "Eric Gordon",
#     "query": "%22Eric+Gordon%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Kings+of+Leon%22",
#     "name": "Kings of Leon",
#     "query": "%22Kings+of+Leon%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Princess+Diana%22",
#     "name": "Princess Diana",
#     "query": "%22Princess+Diana%22",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Big+Sean%22",
#     "name": "Big Sean",
#     "query": "%22Big+Sean%22",
#     "tweet_volume": 36977
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23MagicianDatingProblems",
#     "name": "#MagicianDatingProblems",
#     "query": "%23MagicianDatingProblems",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23TheLeftovers",
#     "name": "#TheLeftovers",
#     "query": "%23TheLeftovers",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23IntoTheBadlands",
#     "name": "#IntoTheBadlands",
#     "query": "%23IntoTheBadlands",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23OnceUponAMusical",
#     "name": "#OnceUponAMusical",
#     "query": "%23OnceUponAMusical",
#     "tweet_volume": 62479
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23UnitedShades",
#     "name": "#UnitedShades",
#     "query": "%23UnitedShades",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23Veep",
#     "name": "#Veep",
#     "query": "%23Veep",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23IWishINeverHadTo",
#     "name": "#IWishINeverHadTo",
#     "query": "%23IWishINeverHadTo",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23SallyYatesIsAPatriot",
#     "name": "#SallyYatesIsAPatriot",
#     "query": "%23SallyYatesIsAPatriot",
#     "tweet_volume": 105190
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23LastWeekTonight",
#     "name": "#LastWeekTonight",
#     "query": "%23LastWeekTonight",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23WhyIHatedSchool",
#     "name": "#WhyIHatedSchool",
#     "query": "%23WhyIHatedSchool",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23KUWTK",
#     "name": "#KUWTK",
#     "query": "%23KUWTK",
#     "tweet_volume": 11534
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23ShadesOfBlue",
#     "name": "#ShadesOfBlue",
#     "query": "%23ShadesOfBlue",
#     "tweet_volume": 11041
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%234WordLetDowns",
#     "name": "#4WordLetDowns",
#     "query": "%234WordLetDowns",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23PlaylistatUniversal",
#     "name": "#PlaylistatUniversal",
#     "query": "%23PlaylistatUniversal",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23TheArrangement",
#     "name": "#TheArrangement",
#     "query": "%23TheArrangement",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23LastManOnEarth",
#     "name": "#LastManOnEarth",
#     "query": "%23LastManOnEarth",
#     "tweet_volume": null
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23Next100Days",
#     "name": "#Next100Days",
#     "query": "%23Next100Days",
#     "tweet_volume": 64398
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23MasterChefMx",
#     "name": "#MasterChefMx",
#     "query": "%23MasterChefMx",
#     "tweet_volume": 39744
#    }
#   ],
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']]) 

for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))

print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('----------', 'world')
# #نغرد_عشان,#IntoTheBadlands,#RHOA,Joe West,#ProfileInCourage,#AltaTensión,#LaVozKids,#FodderScam,#سقوط_طالب_من_الدرج,#محمد_بن_سلمان_يزلزل_ايران,#SallyYatesIsAPatriot,#DeboDecir,#EntMEWomen,#pazartesi,#SinMiedoTuca,#SegundaComClubeSDV,#MagicianDatingProblems,#Independiente,#PurposeTourManila,#DafBama2017_SuperJunior,#حاجات_تفتح_نفسي,#NoMeGustaQue,#MLBxESPN,#DANCEDANCE,Erica Rivas,#OnceUponAMusical,#في_حبك_قلت,#iBribedKejriwal,#ShowtimeMAYForever,#تجمع_التربيه_الخاصه_بجده2,#무엇을_어디에_넣어줄지_말해보자,GW明け,#CorazonesRotosMC,#VenezuelaUrgente,#MasterChefMx,Guerra Mundial Z,#EnLiguillaVoy,Stranger Things,#AmericanRaceTNT,#JesusCristoEstáVivo,#MTVAwards,#FelizLunes,#kokkai,#MTVActAppVillalobos,Jake Arrieta,#BillionsSeasonFinale,#MejorHablar,#unite2017tokyo,#صباحات_الاهلي,#اجد_في_عيناك
# ('----------', 'us')
# Kings of Leon,Wade Davis,#LastWeekTonight,#IntoTheBadlands,#RHOA,Joe West,Aaron Boone,#ProfileInCourage,#IWishINeverHadTo,#SallyYatesIsAPatriot,Eric Gordon,#LastManOnEarth,Chris Carter,#MagicianDatingProblems,#PlaylistatUniversal,Princess Diana,#UnitedShades,#TheLeftovers,#OnceUponAMusical,Bryant,#ShadesOfBlue,Big Sean,#Next100Days,Cheesecake Factory,#WhyIHatedSchool,#MasterChefMx,Jump Out The Window,Chasen Shreve,Stranger Things,#AmericanRaceTNT,#4WordLetDowns,#TheArrangement,#MTVAwards,Bobby Brown,#Billions,#Veep,Jake Arrieta,New MLB,Adam Warren,#KUWTK,Brian Duensing,Patrick Beverley
# ('----------', 'san diego')
# Kings of Leon,Wade Davis,#LastWeekTonight,#IntoTheBadlands,#RHOA,#digitalhealth,Aaron Boone,#ProfileInCourage,#SiliconValleyHBO,#IWishINeverHadTo,#SallyYatesIsAPatriot,Eric Gordon,#LastManOnEarth,#MagicianDatingProblems,#PlaylistatUniversal,Princess Diana,#UnitedShades,#TheLeftovers,#OnceUponAMusical,Bryant,#GoCubsGo,#ShadesOfBlue,Big Sean,#Next100Days,Cheesecake Factory,#WhyIHatedSchool,#NW88JR,#Yankees,#MasterChefMx,Jump Out The Window,#LigaMXeng,Chasen Shreve,Stranger Things,#AmericanRaceTNT,#4WordLetDowns,#TheArrangement,#MTVAwards,Bobby Brown,#frenchelection,#Billions,#Veep,Jake Arrieta,New MLB,Adam Warren,#KUWTK,Brian Duensing,Patrick Beverley
# ('==========', 'intersection of world and us')
# {'#MTVAwards', '#IntoTheBadlands', '#MagicianDatingProblems', '#RHOA', 'Joe West', '#MasterChefMx', '#ProfileInCourage', 'Jake Arrieta', '#OnceUponAMusical', '#SallyYatesIsAPatriot', 'Stranger Things', '#AmericanRaceTNT'}
# ('==========', 'intersection of us and san-diego')
# {'Kings of Leon', 'Wade Davis', '#LastWeekTonight', '#IntoTheBadlands', '#RHOA', 'Aaron Boone', '#ProfileInCourage', '#IWishINeverHadTo', '#SallyYatesIsAPatriot', 'Eric Gordon', '#LastManOnEarth', '#MagicianDatingProblems', '#PlaylistatUniversal', 'Princess Diana', '#UnitedShades', '#TheLeftovers', '#OnceUponAMusical', 'Bryant', '#ShadesOfBlue', 'Big Sean', '#Next100Days', 'Cheesecake Factory', '#WhyIHatedSchool', '#MasterChefMx', 'Jump Out The Window', 'Chasen Shreve', 'Stranger Things', '#AmericanRaceTNT', '#4WordLetDowns', '#TheArrangement', '#MTVAwards', 'Bobby Brown', '#Billions', '#Veep', 'Jake Arrieta', 'New MLB', 'Adam Warren', '#KUWTK', 'Brian Duensing', 'Patrick Beverley'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#MTVAwards' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']

# %%
len(statuses)
# Out:
# 100

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 91

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @Kaitiii: Found these crazy kids backstage at the #MTVAwards festival 🌸 @JackAllTimeLow @zackalltimelow @AlexAllTimeLow @riandawson http…',
#  'RT @blkgirlsrelate: shooketh #mtvawards https://t.co/H2CEtJpJ3G',
#  'RT @THR: Emma Watson: "This is the first acting award in history that doesn\'t separate nominees by their sex." #MTVAwards https://t.co/Adpo…',
#  'RT @__girlsgonewild: 7 พฤษภาคม : ภาพล่าสุด Cara Delevingne ที่งาน #MTVAwards\xa0 จัดขึ้นในลอสแองเจลิส หล่อเข้มมาก ใจสั่นไปหมดแล้วพี่ร่า 😍😝 htt…',
#  'RT @13ReasonsWhyBRA: 📸 | Christian Navarro via Instagram com o Dylan Minnette.\n#MTVAwards https://t.co/4zh4dPtnUr',
#  'RT @Camila_Cabello: GUYYS!! So excited to perform "Hey Ma" w @pitbull and @JBALVIN , see you tonight at 8/7c on @MTV! #MTVAwards https://t.…',
#  'RT @ohmxrvel: Ganó Stranger Things. La vida me sonríe  #MTVAwards',
#  "RT @MTVteenwolf: Look who I ran into! @tylergposey at the #mtvawards + #ToyotaCHR after party 😍 let's go make some mischief! https://t.co/n…",
#  'RT @MTV: ICYMI -- @milliebbrown won Best Actor in a TV Show at the #MTVAwards: https://t.co/X4E1meCn9v https://t.co/ynSwF9VMlt',
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "in_reply_to_screen_name": null,
#  "lang": "en",
#  "truncated": false,
#  "metadata": {
#   "result_type": "recent",
#   "iso_language_code": "en"
#  },
#  "created_at": "Mon May 08 05:57:34 +0000 2017",
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 20468965,
#     "screen_name": "Kaitiii",
#     "indices": [
#      3,
#      11
#     ],
#     "name": "Kaitlyn Vella",
#     "id_str": "20468965"
#    },
#    {
#     "id": 18378446,
#     "screen_name": "JackAllTimeLow",
#     "indices": [
#      75,
#      90
#     ],
#     "name": "Jack Barakat",
#     "id_str": "18378446"
#    },
#    {
#     "id": 29300489,
#     "screen_name": "zackalltimelow",
#     "indices": [
#      91,
#      106
#     ],
#     "name": "Zachary Merrick",
#     "id_str": "29300489"
#    },
#    {
#     "id": 18734884,
#     "screen_name": "AlexAllTimeLow",
#     "indices": [
#      107,
#      122
#     ],
#     "name": "Alexander William",
#     "id_str": "18734884"
#    },
#    {
#     "id": 22596730,
#     "screen_name": "riandawson",
#     "indices": [
#      123,
#      134
#     ],
#     "name": "Rian Dawson",
#     "id_str": "22596730"
#    }
#   ],
#   "hashtags": [
#    {
#     "text": "MTVAwards",
#     "indices": [
#      53,
#      63
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "favorite_count": 0,
#  "favorited": false,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "geo": null,
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "is_quote_status": false,
#  "retweet_count": 245,
#  "retweeted_status": {
#   "in_reply_to_screen_name": null,
#   "lang": "en",
#   "truncated": true,
#   "metadata": {
#    "result_type": "recent",
#    "iso_language_code": "en"
#   },
#   "created_at": "Sun May 07 21:36:47 +0000 2017",
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 18378446,
#      "screen_name": "JackAllTimeLow",
#      "indices": [
#       62,
#       77
#      ],
#      "name": "Jack Barakat",
#      "id_str": "18378446"
#     },
#     {
#      "id": 29300489,
#      "screen_name": "zackalltimelow",
#      "indices": [
#       78,
#       93
#      ],
#      "name": "Zachary Merrick",
#      "id_str": "29300489"
#     },
#     {
#      "id": 18734884,
#      "screen_name": "AlexAllTimeLow",
#      "indices": [
#       94,
#       109
#      ],
#      "name": "Alexander William",
#      "id_str": "18734884"
#     }
#    ],
#    "hashtags": [
#     {
#      "text": "MTVAwards",
#      "indices": [
#       40,
#       50
#      ]
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/5Pw7j1DbiZ",
#      "indices": [
#       111,
#       134
#      ],
#      "expanded_url": "https://twitter.com/i/web/status/861334017878052864",
#      "display_url": "twitter.com/i/web/status/8\u2026"
#     }
#    ]
#   },
#   "possibly_sensitive": false,
#   "favorite_count": 861,
#   "favorited": false,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "geo": null,
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "is_quote_status": false,
#   "retweet_count": 245,
#   "retweeted": false,
#   "in_reply_to_user_id_str": null,
#   "contributors": null,
#   "id_str": "861334017878052864",
#   "user": {
#    "lang": "en",
#    "is_translation_enabled": false,
#    "profile_sidebar_border_color": "000000",
#    "is_translator": false,
#    "created_at": "Mon Feb 09 21:26:58 +0000 2009",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/1AGQTOPksO",
#        "indices": [
#         0,
#         23
#        ],
#        "expanded_url": "http://Instagram.com/kaitlynvella",
#        "display_url": "Instagram.com/kaitlynvella"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "description": "social media manager @mtv, the end.",
#    "protected": false,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000171294397/bDvCchVV.jpeg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/849427592218324992/DZQ7llkP_normal.jpg",
#    "default_profile": false,
#    "time_zone": "Eastern Time (US & Canada)",
#    "id": 20468965,
#    "notifications": false,
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000171294397/bDvCchVV.jpeg",
#    "geo_enabled": true,
#    "contributors_enabled": false,
#    "profile_sidebar_fill_color": "252429",
#    "profile_text_color": "666666",
#    "default_profile_image": false,
#    "profile_background_color": "000000",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/849427592218324992/DZQ7llkP_normal.jpg",
#    "profile_use_background_image": false,
#    "has_extended_profile": true,
#    "profile_link_color": "430084",
#    "name": "Kaitlyn Vella",
#    "profile_background_tile": false,
#    "id_str": "20468965",
#    "utc_offset": -14400,
#    "friends_count": 994,
#    "favourites_count": 18087,
#    "verified": true,
#    "following": false,
#    "follow_request_sent": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/20468965/1421809462",
#    "listed_count": 193,
#    "url": "https://t.co/1AGQTOPksO",
#    "screen_name": "Kaitiii",
#    "statuses_count": 26137,
#    "translator_type": "regular",
#    "location": "new york",
#    "followers_count": 22980
#   },
#   "id": 861334017878052864,
#   "place": null,
#   "text": "Found these crazy kids backstage at the #MTVAwards festival \ud83c\udf38 @JackAllTimeLow @zackalltimelow @AlexAllTimeLow\u2026 https://t.co/5Pw7j1DbiZ",
#   "coordinates": null,
#   "in_reply_to_status_id": null
#  },
#  "in_reply_to_user_id_str": null,
#  "contributors": null,
#  "retweeted": false,
#  "id_str": "861460043052466176",
#  "user": {
#   "lang": "en",
#   "is_translation_enabled": false,
#   "profile_sidebar_border_color": "FFFFFF",
#   "is_translator": false,
#   "created_at": "Fri Nov 01 22:01:19 +0000 2013",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/ZE3SBnrMHG",
#       "indices": [
#        0,
#        23
#       ],
#       "expanded_url": "https://www.wattpad.com/user/ILove5SOS247",
#       "display_url": "wattpad.com/user/ILove5SOS\u2026"
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "description": "LOML is @lovemarissa143/ R5 1-27-16/ SLFL 9-2-16/ HV 3-7-17/ Dalton /HV 3/6/ The Vamps band acc + 3/4 /R5 band acc/ mom of 5SOFF",
#   "protected": false,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/550548662611226626/7juUPicI.jpeg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/856946825412001792/__tJe8Yp_normal.jpg",
#   "default_profile": false,
#   "time_zone": null,
#   "id": 2169144331,
#   "notifications": false,
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/550548662611226626/7juUPicI.jpeg",
#   "geo_enabled": true,
#   "contributors_enabled": false,
#   "profile_sidebar_fill_color": "E3E2DE",
#   "profile_text_color": "634047",
#   "default_profile_image": false,
#   "profile_background_color": "EDECE9",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/856946825412001792/__tJe8Yp_normal.jpg",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "profile_link_color": "19CF86",
#   "name": "Sarah",
#   "profile_background_tile": true,
#   "id_str": "2169144331",
#   "utc_offset": null,
#   "friends_count": 2608,
#   "favourites_count": 7329,
#   "verified": false,
#   "following": false,
#   "follow_request_sent": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/2169144331/1492411155",
#   "listed_count": 49,
#   "url": "https://t.co/ZE3SBnrMHG",
#   "screen_name": "ILove5SOS247",
#   "statuses_count": 233548,
#   "translator_type": "none",
#   "location": "cuddling with Michael",
#   "followers_count": 3276
#  },
#  "id": 861460043052466176,
#  "place": null,
#  "text": "RT @Kaitiii: Found these crazy kids backstage at the #MTVAwards festival \ud83c\udf38 @JackAllTimeLow @zackalltimelow @AlexAllTimeLow @riandawson http\u2026",
#  "coordinates": null,
#  "in_reply_to_status_id": null
# }

# %%
import json

# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 245
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @Kaitiii: Found these crazy kids backstage at the #MTVAwards festival \ud83c\udf38 @JackAllTimeLow @zackalltimelow @AlexAllTimeLow @riandawson http\u2026",
#  "RT @blkgirlsrelate: shooketh #mtvawards https://t.co/H2CEtJpJ3G",
#  "RT @THR: Emma Watson: \"This is the first acting award in history that doesn't separate nominees by their sex.\" #MTVAwards https://t.co/Adpo\u2026",
#  "RT @__girlsgonewild: 7 \u0e1e\u0e24\u0e29\u0e20\u0e32\u0e04\u0e21 : \u0e20\u0e32\u0e1e\u0e25\u0e48\u0e32\u0e2a\u0e38\u0e14 Cara Delevingne \u0e17\u0e35\u0e48\u0e07\u0e32\u0e19 #MTVAwards\u00a0 \u0e08\u0e31\u0e14\u0e02\u0e36\u0e49\u0e19\u0e43\u0e19\u0e25\u0e2d\u0e2a\u0e41\u0e2d\u0e07\u0e40\u0e08\u0e25\u0e34\u0e2a \u0e2b\u0e25\u0e48\u0e2d\u0e40\u0e02\u0e49\u0e21\u0e21\u0e32\u0e01 \u0e43\u0e08\u0e2a\u0e31\u0e48\u0e19\u0e44\u0e1b\u0e2b\u0e21\u0e14\u0e41\u0e25\u0e49\u0e27\u0e1e\u0e35\u0e48\u0e23\u0e48\u0e32 \ud83d\ude0d\ud83d\ude1d htt\u2026",
#  "RT @13ReasonsWhyBRA: \ud83d\udcf8 | Christian Navarro via Instagram com o Dylan Minnette.\n#MTVAwards https://t.co/4zh4dPtnUr"
# ]
# [
#  "Kaitiii",
#  "JackAllTimeLow",
#  "zackalltimelow",
#  "AlexAllTimeLow",
#  "riandawson"
# ]
# [
#  "MTVAwards",
#  "mtvawards",
#  "MTVAwards",
#  "MTVAwards",
#  "MTVAwards"
# ]
# [
#  "RT",
#  "@Kaitiii:",
#  "Found",
#  "these",
#  "crazy"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('RT', 87), ('#MTVAwards', 74), ('the', 42), ('at', 26), ('@MTV:', 17), ('a', 12), ('to', 12), ('for', 10), ('and', 9), ('in', 8)]
#
# [('MTV', 19), ('Camila_Cabello', 4), ('tylergposey', 4), ('13ReasonsWhyBRA', 3), ('Zendaya', 3), ('milliebbrown', 3), ('sollgmz', 3), ('pitbull', 2), ('__girlsgonewild', 2), ('MTVteenwolf', 2)]
#
# [('MTVAwards', 82), ('mtvawards', 7), ('13ReasonsWhy', 2), ('MTVMovieAwards2017', 2), ('KristenStewart', 1), ('ZacEfron', 1), ('Logan', 1), ('moonlight', 1), ('TheFastAndTheFurious', 1), ('transformers', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*30)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ******************************
# RT                   |     87
# #MTVAwards           |     74
# the                  |     42
# at                   |     26
# @MTV:                |     17
# a                    |     12
# to                   |     12
# for                  |     10
# and                  |      9
# in                   |      8
#
#     Screen Name      | Count
# ******************************
# MTV                  |     19
# Camila_Cabello       |      4
# tylergposey          |      4
# 13ReasonsWhyBRA      |      3
# Zendaya              |      3
# milliebbrown         |      3
# sollgmz              |      3
# pitbull              |      2
# __girlsgonewild      |      2
# MTVteenwolf          |      2
#
#       Hashtag        | Count
# ******************************
# MTVAwards            |     82
# mtvawards            |      7
# 13ReasonsWhy         |      2
# MTVMovieAwards2017   |      2
# KristenStewart       |      1
# ZacEfron             |      1
# Logan                |      1
# moonlight            |      1
# TheFastAndTheFurious |      1
# transformers         |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*30)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:5])
# Out:
#  Count  |   Screen Name   | Text
# ******************************
#    9967 |  Camila_Cabello | RT @Camila_Cabello: GUYYS!! So excited to perform
#         |                 | "Hey Ma" w @pitbull and @JBALVIN , see you tonight
#         |                 |  at 8/7c on @MTV! #MTVAwards https://t.…
#    6871 |             MTV | RT @MTV: “You’re the Spiderman!” Here’s your first
#         |                 |  look at a brand new @SpiderManMovie clip, exclusi
#         |                 | vely from the #MTVAwards airing right n…
#    5420 |             MTV | RT @MTV: This is too precious for words. #MTVAward
#         |                 | s https://t.co/Xu7BpoZL84
#    4923 |             MTV | RT @MTV: BE STILL, MY HEART ❤️ #MTVAwards https://
#         |                 | t.co/oYKEY3v8jN
#    4835 |             MTV | RT @MTV: Let @dylanobrien guide you through a firs
#         |                 | t look at Maze Runner: The Death Cure, exclusively
#         |                 |  for the #MTVAwards tonight at 8/7c! 💥…
